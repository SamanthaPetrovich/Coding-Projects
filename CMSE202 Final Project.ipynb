# %% [markdown]
# # Traffic Fatalities

# %% [markdown]
# Group members:
# - Ian Schneider
# - Samantha Petrovich
# - Xinyu Zhang
# - Jeffret Valentic

# %%
import pandas as pd #Import Pandas
import matplotlib.pyplot as plt #Import Matplotlib
import numpy as np #Import numpy
from scipy.stats import pearsonr
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_curve, roc_auc_score, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from sklearn.svm import SVC

# %%
crash_df = pd.read_csv('accident_v2.csv')
crash_df.head()

# %%
corrMatrix = crash_df.corr()
fig, ax = plt.subplots(figsize=(20,20))        
sns.heatmap(data=corrMatrix,annot=True,ax=ax)

# %%
feat = crash_df.drop(columns = 'DRUNK_DR')
labels = crash_df['DRUNK_DR']

# %%
feat_train, feat_test, labels_train ,labels_test = train_test_split(feat,labels)

# %%
pd.set_option('display.max_columns', 100)
CAS_df = pd.read_csv('Crash_Analysis_System__CAS__Data.csv')
CAS_df.head()
# Out:
#             X             Y  OBJECTID  advisorySpeed  areaUnitID  bicycle  \
# 0  1750919.00  5.427734e+06         1            NaN    576700.0      0.0
# 1  1728170.00  6.006564e+06         2            NaN    501815.0      0.0
# 2  1767790.94  5.905093e+06         3            NaN    523722.0      0.0
# 3  1681006.00  6.024878e+06         4            NaN    504502.0      1.0
# 4  1756984.00  5.918844e+06         5            NaN    514301.0      0.0
#
#    bridge  bus  carStationWagon  cliffBank crashDirectionDescription  \
# 0     0.0  0.0              2.0        1.0                     South
# 1     0.0  0.0              0.0        0.0                     North
# 2     NaN  0.0              1.0        NaN                      East
# 3     NaN  0.0              1.0        NaN                      Null
# 4     NaN  1.0              1.0        NaN                     North
#
#    crashFinancialYear   crashLocation1              crashLocation2  \
# ...

# %%
new_CAS_df = CAS_df.drop(columns = ['advisorySpeed','bridge','cliffBank','crashLocation1','crashLocation2'
                                    ,'crashRoadSideRoad','debris','ditch','fence','guardRail','holiday','houseOrBuilding',
                                   'intersection','kerb','objectThrownOrDropped','otherObject','otherVehicleType',
                                    'overBank', 'parkedVehicle', 'pedestrian','phoneBoxEtc','postOrPole','roadCharacter'
                                   ,'roadworks','slipOrFlood','strayAnimal','temporarySpeedLimit','trafficControl',
                                    'trafficIsland','trafficSign','train','tree','unknownVehicleType','vehicle','waterRiver',
                                   'weatherB'])

# %%
new_CAS_df.head()
# Out:
#             X             Y  OBJECTID  areaUnitID  bicycle  bus  \
# 0  1750919.00  5.427734e+06         1    576700.0      0.0  0.0
# 1  1728170.00  6.006564e+06         2    501815.0      0.0  0.0
# 2  1767790.94  5.905093e+06         3    523722.0      0.0  0.0
# 3  1681006.00  6.024878e+06         4    504502.0      1.0  0.0
# 4  1756984.00  5.918844e+06         5    514301.0      0.0  1.0
#
#    carStationWagon crashDirectionDescription  crashFinancialYear  \
# 0              2.0                     South                2009
# 1              0.0                     North                2008
# 2              1.0                      East                2019
# 3              1.0                      Null                2008
# 4              1.0                     North                2002
#
#       crashSeverity crashSHDescription  crashYear directionRoleDescription  \
# 0  Non-Injury Crash                 No       2008                    North
# ...
